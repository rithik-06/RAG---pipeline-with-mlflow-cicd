# %%
import torch
from torch import nn
from torch.nn import functional as F

# %%
from unsloth import Unsloth, UnslothConfig
# Define the configuration for the Unsloth model
config = UnslothConfig(
    vocab_size=30522,  # Size of the vocabulary
    max_position_embeddings=512,  # Maximum sequence length
    num_hidden_layers=12,  # Number of transformer layers
    num_attention_heads=12,  # Number of attention heads
    hidden_size=768,  # Size of the hidden layers
    intermediate_size=3072,  # Size of the intermediate layers
    hidden_act="gelu",  # Activation function       
    initializer_range=0.02,  # Standard deviation for weight initialization
    layerdrop=0.1,  # Dropout probability for the layers
    use_cache=True,  # Whether to use caching for faster decoding
    num_codebooks=4,  # Number of codebooks for quantization
    codebook_size=256,  # Size of each codebook
    tie_word_embeddings=False,  # Whether to tie input and output word embeddings

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
